# %% [markdown]
# # The Book Keeper's Apprentice - Dicts & List

# %%
# Importing libraries
import time
from pprint import pprint
import pickle

# Importing data
from helper import books_dict, authors_list, books_list

# %%
# Print first 5 elements from books_dict
print('Books_dict')
print(list(books_dict.items())[:5])

# %%
# Print first 5 elements from authors_list
print("Authors_list")
authors_list[:5]

# %%
# Print first 5 elements from books_list
print("Books_list")
books_list[:5]

# %% [markdown]
# ## Part 1 - Searching for Book 1: `"Harry Potter and the Half-Blood Prince (Harry Potter  #6)"`

# %% [markdown]
# The highness needs a couple of books. Most importantly, they need the name of the author of these books. Can you fetch it for her?

# %% [markdown]
# ### Using `books_list`, fetch the author name for "Harry Potter and the Half-Blood Prince (Harry Potter  #6)"
#
# ![alt text](list_fig.JPG)

# %%
### edTest(test_1) ###
## DO NOT REMOVE ABOVE LINE ##

#The highness has once again asked you for a book of the name 
# - "Harry Potter and the Half-Blood Prince (Harry Potter  #6)"

#Let's start the clock
start_time = time.time()

print("Searching through the list...",end='\n')

#Book title
book_title = "Harry Potter and the Half-Blood Prince (Harry Potter  #6)"

#Variable to store the index of the book
book_index = None
#Go through the books list and return the index of the book in the list
for i in range(len(books_list)):
    if books_list[___] == ___:
        book_index = ___
        break

print("Book Found in Index "+str(___))

#Fetch the author's name from the `authors_list` using `book_index`
author_name = ___[___]
print(f"The author of the book is {author_name}")

#Let's measure how much time it took
list_duration_book_1 = time.time() - start_time
print(f"--- Searching took {list_duration_book_1} seconds ---")

# %% [markdown]
# ### Using `books_dict`, fetch the author name for "Harry Potter and the Half-Blood Prince (Harry Potter  #6)"
#
# We can definitely do better than this. Let's use dictionaries to store information about the books and the details of the books.
#
# Search for the books from the dictionary and fetch the author name.

# %%
### edTest(test_2) ###
## DO NOT REMOVE ABOVE LINE ##

#Let's start the clock
start_time = time.time()

print("Searching through the dict...")

#Book title
book_title = "Harry Potter and the Half-Blood Prince (Harry Potter  #6)"

#Fetch the value from `books_dict` using the title key
author_name = ___

print("The author of the book is "+str(author_name))

#Let's measure how much time it took
dict_duration_book_1 = time.time() - start_time
print(f"--- Searching took {dict_duration_book_1} seconds --- ")

# %%
#Comparison of dictionary_duration and list_duration - calculate the ratio of the same
print(f"Ratio of Dictionary Search to List Search - {dict_duration_book_1/list_duration_book_1:0.2f}")

# %% [markdown]
# Please note that in this case, your `book_index` was relatively small. This means that the book is placed in earlier positions.

# %% [markdown]
# ## Part 2 - Searching for book 2: `"The Holaindaise Chronicles of the Far West"`

# %% [markdown]
# ### Using `books_list`, fetch the author name of "The Holaindaise Chronicles of the Far West"

# %%
### edTest(test_3) ###
## DO NOT REMOVE ABOVE LINE ##

#The Princess has once again asked you for a book of the name 
# - "The Holaindaise Chronicles of the Far West"

#Let's start the clock
start_time = time.time()

print("Searching through the list...", end = '\n')

#title of the book
book_title = 'The Holaindaise Chronicles of the Far West'

#Variable to store the book_index
book_index = None
#Go through the books list and return the index of the book in the list
for i in range(len(___)):
    if books_list[___] == ___:
        book_index = ___
        break

#Printing the index of the book
print("Book Found in Index "+str(___))

#Fetch the author from the `authors_list` using book_index
author_name = ___

#Print the name of the author of the book
print("The author of the book is "+author_name, end='\n')

#Let's measure how much time it took
list_duration_book_2 = time.time() - start_time
print(f"--- Searching took {list_duration_book_2} seconds ---")

# %% [markdown]
# ### Using `books_dict`, fetch the author name of "The Holaindaise Chronicles of the Far West"

# %%
### edTest(test_4) ###
## DO NOT REMOVE ABOVE LINE ##

#Let's start the clock
start_time = time.time()

print("Searching through the dict...", end="\n")

#Give the title of the book - "The Holaindaise Chronicles of the Far West"
title = "The Holaindaise Chronicles of the Far West"

#Fetch the author name from `books_dict` using the title key
fetched_author_name = ___[___]

print("The author of the book is "+fetched_author_name, end="\n")

#Let's measure how much time it took
dict_duration_book_2 = time.time() - start_time
print(f"--- Searching took {dict_duration_book_2} seconds --- ")

# %%
#Comparison of dictionary_duration and list_duration - calculate the ratio of the same
print(f"Ratio of Dictionary Search to List Search - {dict_duration_book_2/list_duration_book_2:0.2f}")

# %% [markdown]
# Please note that in this case, your `book_index` was relatively large. This means that the book is placed in later positions.
#
# Do you observe the relation between position and the time it is taking to fetch values from that position? How is it differing for a list vs. a dictionary?

# %% [markdown]
# ### ⏸ Which took lesser time - searching through a list or searching through the dictioanary? Why do you think this is so?
#
# #### A. `Dictionary was faster due to hashability`
# #### B. `List was faster time due to iterations`
# #### C. `Dictionary took more time due to immutability`

# %%
### edTest(test_6) ###
## DO NOT REMOVE ABOVE LINE ##

#Enter the your choice here - "A" or "B" or "C" 
your_answer = '___'

# %% [markdown]
# ## Part 3 - Create your own dictionary
#
# Create a dictionary named `authors_book_freq` where the:
# * `key --->` the author name
# * `value --->` no. of books
#
# ### Hint: Use `.count()`

# %%
### edTest(test_5) ###
## DO NOT REMOVE ABOVE LINE ##

#Initialize an empty dictionary
authors_book_freq = ___

#Let's take only the first author name in the author string 
#eg: if author name is "J.K Rowling/Mary Sharwia", we select only "J.K Rowling"
#Initialize new list
cleaned_authors_list = ____

#Loop through the `authors_list`
for author in authors_list[:10_000]:
    #Get only the first author from the string
    first_author = author.split('/')[0]
    #Append first_author string to cleaned_authors_list
    cleaned_authors_list.append(___)

#Loop through names of author in `cleaned_authors_list` 
for ___ in ___:
    #Create dictionary where key--> author name; value --->count of books written by the author
    authors_book_freq[___] = cleaned_authors_list.count(___)

#Display dictionary using pprint
# pprint is a special type of print statement
# that prints data structures in a nice way
pprint(___)

# %% [markdown]
# Run the code cell below to see the sorted dictionary.

# %%
sorted(authors_book_freq.items(), key = lambda x: -x[1])
