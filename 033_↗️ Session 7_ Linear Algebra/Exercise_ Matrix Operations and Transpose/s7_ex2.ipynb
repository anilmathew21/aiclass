# %%
import numpy as np

# %%
### edTest(test_matrix_addition) ###
## DO NOT REMOVE ABOVE LINE ##

# Function to add two matrices
def matrix_addition(A, B):
    result = ___
    return result

# %%
### edTest(test_matrix_subtraction) ###
## DO NOT REMOVE ABOVE LINE ##

# Function to subtract two matrices
def matrix_subtraction(A, B):
    result = ___
    return result

# %%
### edTest(test_hadamard_product) ###
## DO NOT REMOVE ABOVE LINE ##

# Function to compute Hadamard product of two matrices
def hadamard_product(A, B):
    result = ___
    return result

# %%
### edTest(test_matrix_transpose) ###
## DO NOT REMOVE ABOVE LINE ##

# Function to compute transpose of a matrix
def matrix_transpose(A):
    result = ___
    return result
