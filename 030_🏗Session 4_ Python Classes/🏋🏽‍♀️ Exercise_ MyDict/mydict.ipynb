# %% [markdown]
# ## `Build your own Dictionary!`
#
# This is a somewhat challenging excercise, but we are confident that you can complete it.

# %%
### edTest(test_class) ###
class MyDict(object):
    """
    Follow the instructions of this docstring to finish this function. This class will 
    perform the same function as a dictionary. 
    
    [background information about hashing]
    
    Save the following attributes:
    -------
    size: the size of the dictionary 
    
    length: initialize to zero. 
        This variable will keep track of the number of items in the dictionary.
    
    storage: a list of lists. Initialize this with empty lists. 
        This list should have length self.size.
    
    
    Finish the following Methods 
    -------
    
    __init__:
     create an empty list of length size (an input argument) 
     that is by default sufficiently large.
    
    __setitem__:
        1. get a storage index by calling the hash key function
        2. iterate through the storage list at the storage index. 
        3. if the key matches the first element, set the first item to the value.
        4. at the conclusion of this loop append a new [key, value] list to that storage location.
    
    __getitem__:
        1. get a storage index by calling the hash key function
        2. iterate through the storage list at the storage index. 
        3. if the key matches the first element, 
        4. return the value at the second list position.
        5. otherwise raise a keyerror with a reasonable message.
    
    __repr__: 
        returns the 
        string representation of a dictionary: {'key' : value, ...}

    hash_key: this function should return a key hash modulo the size.
    
    
    """
    
    def hash_key(self, key) -> int:
        ___
        return ___
        
    def __init__(self, size=1000) -> None:
        ___

    def __setitem__(self, key, value):
        ___

    def __getitem__(self, key):
        storage_idx = self.hash_key(key)
        for ___ in ___:
            if ___:
                return ___
        raise KeyError( ___ )
        
    def __repr__(self):
        ___
        
    def __str__():
        ___

    def __len__():
        ___
    
    def __repr__():
        ___

# %% [markdown]
# Create and test an object instance of your class:

# %%
#instanciate a MyDict
my_dict = MyDict()

# %%
#assign the following
my_dict["cat"] = "tiger"
my_dict["dog"] = "wolf"
my_dict["monkey"] = "human"

# %%
#loop the the dictionary elements with .items() and print the pairs of keys and values
for key in ["cat", "dog", "monkey"]:
    print(my_dict[key])
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-1-1de4f445df98> in <module>
#       1 #loop the the dictionary elements with .items() and print the pairs of keys and values
#       2 for key in ["cat", "dog", "monkey"]:
# ----> 3     print(my_dict[key])
#
# <ipython-input-1-43922e533e2e> in __getitem__(self, key)
#      55     def __getitem__(self, key):
#      56         storage_idx = self.hash_key(key)
# ---> 57         for ___ in ___:
#      58             if ___:
#      59                 return ___
#
# UnboundLocalError: local variable '___' referenced before assignment

# %%
#print your dictionary
print(my_dict)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-cb1bf6233db2> in <module>
#       1 #print your dictionary
# ----> 2 print(my_dict)
#
# TypeError: __str__() takes 0 positional arguments but 1 was given

# %%
#show the object representation of your dictionary
my_dict
